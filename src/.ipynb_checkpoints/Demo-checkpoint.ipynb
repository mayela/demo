# %%
from termcolor import colored

print(colored("Bienvenidos a DevNights!", "blue"))

# %% [markdown]
# # Sintaxis

# %%
import this

# %% [markdown]
# ## Tipos de datos

# %%
entero =12
flotante = 3.1416
cadena = "Live long and proper"
print("%d es un entero" % entero)
print("%f es un flotante" % flotante)
print("%s es una cadena" % cadena)

# %%
tupla = (2, 3, 6, 'pato', 5, 1)
lista = ["hola", 3, 6, 4, "amarillo"]
for t in tupla:
    print("Elemento tupla: %s" % t)
for l in lista:
    print("Elemento lista: %s" % l)

# %%
lista = ["hola", 3, 6, 4, "amarillo"]
for l in lista:
    if type(l) == str:
        print("%s es una cadena" % l)
        print(l.lower())
        print(l.upper())
    else:
        pass

# %% [markdown]
# ## Operadores

# %%
a = 5
b = 8

# Suma
print(a + b)
# Resta
print(a - b)
# Multiplicación
print(a * b)
# División
print(a / b)
# Potencia
print(a ** b)
# 
print(a % b)

# %%
import os
import base64

files = os.listdir(".")
for item in files:
    if os.path.isfile(item):
        with open(item, "rb") as image:
            encode_image = base64.b64encode(image.read())
            encode_image = encode_image.decode("ascii")
            print("%s, %s"%(item, encode_image))
            #escribir en un csv
    else:
        pass
# Out:
# salute.jpg, ...
# python_grecas.png, ...
# guidovanrossum.jpg, ...
# Untitled.ipynb, ...
# import-images.csv, Y29kZTEucHksSXlBdEtpMGdZMjlrYVc1bk9pQjFkR1l0T0NBdEtpMEtDbVp5YjIwZ2RHVnliV052Ykc5eUlHbHRjRzl5ZENCamIyeHZjbVZrQ2dwd2NtbHVkQ2hqYjJ4dmNtVmtLQ0pDYVdWdWRtVnVhV1J2Y3lCaElFUmxkazVwWjJoMGN5RWlMQ0FpWW14MVpTSXBLUW89DQo=
# bb8-stitch.jpg, ...
# docker-go.jpeg, ...
# images2b64.py, ...
# Demo.ipynb, ...
# code1.py, IyAtKi0gY29kaW5nOiB1dGYtOCAtKi0KCmZyb20gdGVybWNvbG9yIGltcG9ydCBjb2xvcmVkCgpwcmludChjb2xvcmVkKCJCaWVudmVuaWRvcyBhIERldk5pZ2h0cyEiLCAiYmx1ZSIpKQo=

# %%
from PIL import Image
guido = Image.open("guidovanrossum.jpg")
guido.show()
help(guido.resize)
# Out:
# Help on method resize in module PIL.Image:
#
# resize(size, resample=0) method of PIL.JpegImagePlugin.JpegImageFile instance
#     Returns a resized copy of this image.
#
#     :param size: The requested size in pixels, as a 2-tuple:
#        (width, height).
#     :param resample: An optional resampling filter.  This can be
#        one of :py:attr:`PIL.Image.NEAREST` (use nearest neighbour),
#        :py:attr:`PIL.Image.BILINEAR` (linear interpolation),
#        :py:attr:`PIL.Image.BICUBIC` (cubic spline interpolation), or
#        :py:attr:`PIL.Image.LANCZOS` (a high-quality downsampling filter).
#        If omitted, or if the image has mode "1" or "P", it is
#        set :py:attr:`PIL.Image.NEAREST`.
#     :returns: An :py:class:`~PIL.Image.Image` object.

# %%
from PIL import Image
salute = Image.open("salute.jpg")
salute.show()
